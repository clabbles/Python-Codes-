# %% [markdown]
# Degenerate Tangent Numbers

# %%
import sympy as sp

# Define symbols
k, t, x, m, lam, = sp.symbols('k t x m lambda')


# Define the generating function
numerator = 2
denominator = (1 + lam * t)**(2 / lam) + 1
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Tangent Numbers
Degenerate_tangent_numbers = []

# Compute the first few Degenerate Tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    Degenerate_tangent_numbers.append(T_n)

# Print the first few Degenerate Tangent Polynomials
for n, poly in enumerate(Degenerate_tangent_numbers):
    print(f"T_(n,1)^((k))(x, u): {poly}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): -1
# T_(n,1)^((k))(x, u): -lambda*(-1 + 2/lambda) + 2
# T_(n,1)^((k))(x, u): -lambda**2*(-2 + 2/lambda)*(-1 + 2/lambda) + 6*lambda*(-1 + 2/lambda) - 6
# T_(n,1)^((k))(x, u): -lambda**3*(-3 + 2/lambda)*(-2 + 2/lambda)*(-1 + 2/lambda) + 8*lambda**2*(-2 + 2/lambda)*(-1 + 2/lambda) + 6*lambda**2*(-1 + 2/lambda)**2 - 36*lambda*(-1 + 2/lambda) + 24

# %%
#checking

import sympy as sp

# Define symbols
k, t, x, m, lam, = sp.symbols('k t x m lambda')


# Define the generating function
numerator = 2
denominator = (1 + lam * t)**(2 / lam) + 1
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Tangent Numbers
#Degenerate_tangent_numbers = []

# Substitute values: k=1, u=-1, x=0
subs_dict = {k: 1, u: -1}

# List to store the results after substitution and limit
evaluated_polynomials = []

# Compute the first few Degenerate Tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    #Degenerate_tangent_numbers.append(T_n)

    # Substitute values for k, u, x
    T_n_subs = T_n.subs(subs_dict)

    # Take the limit as lambda -> 0
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)

    evaluated_polynomials.append(T_n_lam0)

# Print the first few Degenerate Tangent Polynomials
for n, val in enumerate(evaluated_polynomials):
    print(f"T_(n,1)^((k))(x, u): {val}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): -1
# T_(n,1)^((k))(x, u): 0
# T_(n,1)^((k))(x, u): 2
# T_(n,1)^((k))(x, u): 0

# %% [markdown]
# Degenerate Tangent Polynomials

# %%
import sympy as sp

# Define symbols
k, t, x, m, lam, = sp.symbols('k t x m lambda')


# Define the generating function
numerator = 2 * (1 + lam * t)**(x / lam)
denominator = (1 + lam * t)**(2 / lam) + 1
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Tangent Polynomials
Degenerate_tangent_polynomials = []

# Compute the first few Degenerate Tangent Polynomials
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    Degenerate_tangent_polynomials.append(T_n)

# Print the first few Degenerate Tangent Polynomials
for n, poly in enumerate(Degenerate_tangent_polynomials):
    print(f"T_(n,1)^((k))(x, u): {poly}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): x - 1
# T_(n,1)^((k))(x, u): lambda*x*(-1 + x/lambda) - lambda*(-1 + 2/lambda) - 2*x + 2
# T_(n,1)^((k))(x, u): lambda**2*x*(-2 + x/lambda)*(-1 + x/lambda) - lambda**2*(-2 + 2/lambda)*(-1 + 2/lambda) - 3*lambda*x*(-1 + x/lambda) + 6*lambda*(-1 + 2/lambda) + 12*x*(-lambda*(-1 + 2/lambda)/4 + 1/2) - 6
# T_(n,1)^((k))(x, u): lambda**3*x*(-3 + x/lambda)*(-2 + x/lambda)*(-1 + x/lambda) - lambda**3*(-3 + 2/lambda)*(-2 + 2/lambda)*(-1 + 2/lambda) - 4*lambda**2*x*(-2 + x/lambda)*(-1 + x/lambda) + 8*lambda**2*(-2 + 2/lambda)*(-1 + 2/lambda) + 6*lambda**2*(-1 + 2/lambda)**2 + 24*lambda*x*(-1 + x/lambda)*(-lambda*(-1 + 2/lambda)/4 + 1/2) - 36*lambda*(-1 + 2/lambda) + 48*x*(-lambda**2*(-2 + 2/lambda)*(-1 + 2/lambda)/12 + lambda*(-1 + 2/lambda)/2 - 1/2) + 24

# %%
#checking

import sympy as sp

# Define symbols
k, t, x, m, lam, = sp.symbols('k t x m lambda')


# Define the generating function
numerator = 2 * (1 + lam * t)**(x / lam)
denominator = (1 + lam * t)**(2 / lam) + 1
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Tangent polynomials
#Degenerate_tangent_polynomials = []

# Substitute values: k=1, u=-1, x=0
subs_dict = {k: 1, u: -1, x: 0}

# List to store the results after substitution and limit
evaluated_polynomials = []

# Compute the first few Degenerate Tangent polynomials
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    #Degenerate_tangent_numbers.append(T_n)

    # Substitute values for k, u, x
    T_n_subs = T_n.subs(subs_dict)

    # Take the limit as lambda -> 0
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)

    evaluated_polynomials.append(T_n_lam0)

# Print the first few Degenerate Tangent Polynomials
for n, val in enumerate(evaluated_polynomials):
    print(f"T_(n,1)^((k))(x, u): {val}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): -1
# T_(n,1)^((k))(x, u): 0
# T_(n,1)^((k))(x, u): 2
# T_(n,1)^((k))(x, u): 0

# %% [markdown]
# Frobenius-tangent Numbers

# %%
import sympy as sp

# Define symbols
t, x, u = sp.symbols('t x u')

# Define the generating function
numerator = 1-u
denominator = sp.exp(2 * t) - u
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Frobenius-tangent Numbers
Frobenius_tangent_numbers = []

# Compute the first few Frobenius-tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    Frobenius_tangent_numbers.append(T_n)

# Print the first few Frobenius-tangent Numbers
for n, poly in enumerate(Frobenius_tangent_numbers):
    print(f"T_(n,1)^((k))(x, u): {poly}")
# Out:
# T_(n,1)^((k))(x, u): -u/(1 - u) + 1/(1 - u)
# T_(n,1)^((k))(x, u): -2*u/((1 - u)*(u - 1)) + 2/((1 - u)*(u - 1))
# T_(n,1)^((k))(x, u): -2*u*(2/(u - 1) + 4/(u - 1)**2)/(1 - u) + 2*(2/(u - 1) + 4/(u - 1)**2)/(1 - u)
# T_(n,1)^((k))(x, u): -6*u*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(1 - u) + 6*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(1 - u)
# T_(n,1)^((k))(x, u): -24*u*(2/(3*(u - 1)) + 28/(3*(u - 1)**2) + 24/(u - 1)**3 + 16/(u - 1)**4)/(1 - u) + 24*(2/(3*(u - 1)) + 28/(3*(u - 1)**2) + 24/(u - 1)**3 + 16/(u - 1)**4)/(1 - u)

# %%
#checking

import sympy as sp

# Define symbols
t, u = sp.symbols('t u')


# Define the generating function
numerator = 1-u
denominator = sp.exp(2 * t) - u
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Substitute values: u=-1
subs_dict = {u: -1}

# List to store the results after substitution and limit
evaluated_polynomials = []

# Compute the first few Frobenius-tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    #Degenerate_tangent_numbers.append(T_n)

    # Substitute values for u
    T_n_subs = T_n.subs(subs_dict)

    # Take the limit as lambda -> 0
    #T_n_lam0 = sp.limit(T_n_subs, lam, 0)

    evaluated_polynomials.append(T_n_subs)

# Print the first few Frobenius-tangent Numbers
for n, val in enumerate(evaluated_polynomials):
    print(f"T_(n,1)^((k))(x, u): {val}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): -1
# T_(n,1)^((k))(x, u): 0
# T_(n,1)^((k))(x, u): 2
# T_(n,1)^((k))(x, u): 0

# %% [markdown]
# Frobenius-tangent Polynomials

# %%
import sympy as sp

# Define symbols
t, x, u = sp.symbols('t x u')

# Define the generating function
numerator = (1-u) * sp.exp(x * t)
denominator = sp.exp(2 * t) - u
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Frobenius-tangent Polynomials
Frobenius_tangent_polynomials = []

# Compute the first few Frobenius-tangent Polynomials
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    Frobenius_tangent_polynomials.append(T_n)

# Print the first few Frobenius-tangent Polynomials
for n, poly in enumerate(Frobenius_tangent_polynomials):
    print(f"T_(n,1)^((k))(x, u): {poly}")
# Out:
# T_(n,1)^((k))(x, u): -u/(1 - u) + 1/(1 - u)
# T_(n,1)^((k))(x, u): -u*x/(1 - u) - 2*u/((1 - u)*(u - 1)) + x/(1 - u) + 2/((1 - u)*(u - 1))
# T_(n,1)^((k))(x, u): -u*x**2/(1 - u) - 4*u*x/((1 - u)*(u - 1)) - 2*u*(2/(u - 1) + 4/(u - 1)**2)/(1 - u) + x**2/(1 - u) + 4*x/((1 - u)*(u - 1)) + 2*(2/(u - 1) + 4/(u - 1)**2)/(1 - u)
# T_(n,1)^((k))(x, u): -u*x**3/(1 - u) - 6*u*x**2/((1 - u)*(u - 1)) - 6*u*x*(2/(u - 1) + 4/(u - 1)**2)/(1 - u) - 6*u*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(1 - u) + x**3/(1 - u) + 6*x**2/((1 - u)*(u - 1)) + 6*x*(2/(u - 1) + 4/(u - 1)**2)/(1 - u) + 6*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(1 - u)
# ...

# %%
#checking

import sympy as sp

# Define symbols
t, u, x = sp.symbols('t u x')


# Define the generating function
numerator = 1-u
denominator = sp.exp(2 * t) - u
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Substitute values: u=-1, x=0
subs_dict = {u: -1, x=0}

# List to store the results after substitution and limit
evaluated_polynomials = []

# Compute the first few Frobenius-tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    #Degenerate_tangent_numbers.append(T_n)

    # Substitute values for u
    T_n_subs = T_n.subs(subs_dict)

    # Take the limit as lambda -> 0
    #T_n_lam0 = sp.limit(T_n_subs, lam, 0)

    evaluated_polynomials.append(T_n_subs)

# Print the first few Frobenius-tangent Numbers
for n, val in enumerate(evaluated_polynomials):
    print(f"T_(n,1)^((k))(x, u): {val}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): -1
# T_(n,1)^((k))(x, u): 0
# T_(n,1)^((k))(x, u): 2
# T_(n,1)^((k))(x, u): 0

# %% [markdown]
# Degenerate Frobenius-tangent Numbers

# %%
import sympy as sp

# Define symbols
t, u, lam = sp.symbols('t u lambda')

# Define the generating function
numerator = 1-u
denominator = (1 + lam * t)**(2 / lam) - u
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Frobenius-tangent Numbers
Degenerate_Frobenius_tangent_numbers = []

# Compute the first few Degenerate Frobenius-tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the Numbers
    Degenerate_Frobenius_tangent_numbers.append(T_n)

# Print the first few Degenerate Frobenius-tangent Numbers
for n, poly in enumerate(Degenerate_Frobenius_tangent_numbers):
    print(f"T_(n,1)^((k))(x, u): {poly}")
# Out:
# T_(n,1)^((k))(x, u): -u/(1 - u) + 1/(1 - u)
# T_(n,1)^((k))(x, u): -2*u/((1 - u)*(u - 1)) + 2/((1 - u)*(u - 1))
# T_(n,1)^((k))(x, u): -2*u*(lambda*(-1 + 2/lambda)/(u - 1) + 4/(u - 1)**2)/(1 - u) + 2*(lambda*(-1 + 2/lambda)/(u - 1) + 4/(u - 1)**2)/(1 - u)
# T_(n,1)^((k))(x, u): -6*u*(lambda**2*(-2 + 2/lambda)*(-1 + 2/lambda)/(3*(u - 1)) + 4*lambda*(-1 + 2/lambda)/(u - 1)**2 + 8/(u - 1)**3)/(1 - u) + 6*(lambda**2*(-2 + 2/lambda)*(-1 + 2/lambda)/(3*(u - 1)) + 4*lambda*(-1 + 2/lambda)/(u - 1)**2 + 8/(u - 1)**3)/(1 - u)
# ...

# %%
#checking

import sympy as sp

# Define symbols
t, u, lam = sp.symbols('t u lambda')


# Define the generating function
numerator = 1-u
denominator = (1 + lam * t)**(2 / lam) - u
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Substitute values: u=-1, x=0
subs_dict = {u: -1, x: 0}

# List to store the results after substitution and limit
evaluated_polynomials = []

# Compute the first few Frobenius-tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    #Degenerate_tangent_numbers.append(T_n)

    # Substitute values for u, x
    T_n_subs = T_n.subs(subs_dict)

    # Take the limit as lambda -> 0
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)

    evaluated_polynomials.append(T_n_lam0)

# Print the first few Frobenius-tangent Numbers
for n, val in enumerate(evaluated_polynomials):
    print(f"T_(n,1)^((k))(x, u): {val}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): -1
# T_(n,1)^((k))(x, u): 0
# T_(n,1)^((k))(x, u): 2
# T_(n,1)^((k))(x, u): 0

# %% [markdown]
# Degenerate Frobenius-tangent Polynomials

# %%
import sympy as sp

# Define symbols
t, x, u, lam = sp.symbols('t x u lambda')

# Define the generating function
numerator = (1-u) * (1 + lam * t)**(x / lam)
denominator = (1 + lam * t)**(2 / lam) - u
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Frobenius-tangent Polynomials
Degenerate_Frobenius_tangent_polynomials = []

# Compute the first few Degenerate Frobenius-tangent Polynomials
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    Degenerate_Frobenius_tangent_polynomials.append(T_n)

# Print the first few Degenerate Frobenius-tangent Polynomials
for n, poly in enumerate(Degenerate_Frobenius_tangent_polynomials):
    print(f"T_(n,1)^((k))(x, u): {poly}")
# Out:
# T_(n,1)^((k))(x, u): -u/(1 - u) + 1/(1 - u)
# T_(n,1)^((k))(x, u): -u*x/(1 - u) - 2*u/((1 - u)*(u - 1)) + x/(1 - u) + 2/((1 - u)*(u - 1))
# T_(n,1)^((k))(x, u): -lambda*u*x*(-1 + x/lambda)/(1 - u) + lambda*x*(-1 + x/lambda)/(1 - u) - 4*u*x/((1 - u)*(u - 1)) - 2*u*(lambda*(-1 + 2/lambda)/(u - 1) + 4/(u - 1)**2)/(1 - u) + 4*x/((1 - u)*(u - 1)) + 2*(lambda*(-1 + 2/lambda)/(u - 1) + 4/(u - 1)**2)/(1 - u)
# ...

# %%
#checking

import sympy as sp

# Define symbols
t, u, x, lam = sp.symbols('t u x lambda')


# Define the generating function
numerator = (1-u) * (1 + lam * t)**(x / lam)
denominator = (1 + lam * t)**(2 / lam) - u
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Substitute values: u=-1, x=0
subs_dict = {u: -1, x: 0}

# List to store the results after substitution and limit
evaluated_polynomials = []

# Compute the first few Degenerate Frobenius-tangent Polynomials
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    #Degenerate_tangent_numbers.append(T_n)

    # Substitute values for u, x
    T_n_subs = T_n.subs(subs_dict)

    # Take the limit as lambda -> 0
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)

    evaluated_polynomials.append(T_n_lam0)

# Print the first few Degenerate Frobenius-tangent Polynomials
for n, val in enumerate(evaluated_polynomials):
    print(f"T_(n,1)^((k))(x, u): {val}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): -1
# T_(n,1)^((k))(x, u): 0
# T_(n,1)^((k))(x, u): 2
# T_(n,1)^((k))(x, u): 0

# %% [markdown]
# Degenerate Frobenius-type Unipoly-tangent Numbers

# %%
import sympy as sp

# Define symbols
k, t, x, y, lam, u = sp.symbols('k t x y lambda u')
n_sym = sp.symbols('n', integer=True)
p = sp.Function('p')  # Symbolic p(n), no value assigned

# Degenerate exponential: E_lambda^a(t) = (1 + lambda t)^{a / lambda}
def degenerate_exp(a, t, lam):
    return (1 + lam * t)**(a / lam)

# Degenerate falling factorial: (a)_{n,lambda} = a (a - lambda) ... (a - (n - 1)lambda)
def degenerate_falling_factorial(a, n, lam):
    if n == 0:
        return 1
    return sp.prod(a - i * lam for i in range(n))

# Symbolic p(n) left undefined
def p_func(n):
    return p(n)  # symbolic function call

# Define the function u_{k, lambda}(x | p)
def U_k_lambda(x, lam, p_func, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * p_func(n) * x**n) / n**k_val
        for n in range(1, n_terms + 1)
    )

# Construct the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
U_expr = U_k_lambda(log_lambda_expr, lam, p_func=p_func, k_val=1, n_terms=10)
numerator = U_expr * degenerate_exp(x, t, lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Store symbolic Degenerate Frobenius-type Unipoly-tangent Numbers
Degenerate_Frobenius_type_unipoly_tangent_numbers = []

# Compute the first few symbolic numbers
for n in range(n_terms):
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient
    Degenerate_Frobenius_type_unipoly_tangent_numbers.append(sp.simplify(T_n))

# Print symbolic results
for n, poly in enumerate(Degenerate_Frobenius_type_unipoly_tangent_numbers):
    print(f"T_hat_{{{n},λ,p}}^({{k}}) (x; u) = {poly}")
# Out:
# T_hat_{0,λ,p}^({k}) (x; u) = p(1)
# T_hat_{1,λ,p}^({k}) (x; u) = (lambda*(u - 1)**2*p(2) - (u - 1)**2*p(2) + (u - 1)*(2*x - (lambda - 1)*(u - 1))*p(1) + 4*p(1))/(2*(u - 1))
# T_hat_{2,λ,p}^({k}) (x; u) = (-3*lambda*(lambda - 1)*(u - 1)**5*p(2) + lambda*(u - 1)**4*(4*lambda*(u - 1)*p(3) + 3*x*p(2)) + 6*lambda*(u - 1)**3*p(2) + 12*x*(u - 1)**2*p(1) + 3*(lambda - 1)*(u - 1)**5*p(2) + 2*(u - 1)**5*p(3) - 3*(u - 1)**4*(2*lambda*(u - 1)*p(3) + x*p(2)) + (u - 1)**3*(-6*lambda - 3*x*(lambda - 1)*(u - 1) - 3*x*(lambda - x) + (lambda - 2)*(lambda - 1)*(u - 1)**2 + 6)*p(1) - 6*(u - 1)**3*p(2) - 6*(-4*u + (lambda - 2)*(u - 1)**2 + 4)*p(1))/(3*(u - 1)**3)
# ...

# %%
# checking
import sympy as sp

# Define symbols
k, t, x, y, lam, u = sp.symbols('k t x y lambda u')
n_sym = sp.symbols('n', integer=True)
p = sp.Function('p')  # Symbolic p(n), no value assigned

# Degenerate exponential: E_lambda^a(t) = (1 + lambda t)^{a / lambda}
def degenerate_exp(a, t, lam):
    return (1 + lam * t)**(a / lam)

# Degenerate falling factorial: (a)_{n,lambda} = a (a - lambda) ... (a - (n - 1)lambda)
def degenerate_falling_factorial(a, n, lam):
    if n == 0:
        return 1
    return sp.prod(a - i * lam for i in range(n))

#Define p(n) = 1 / (n - 1)!
def p(n):
    return 1 / sp.factorial(n - 1)


# Define the function u_{k, lambda}(x | p)
def U_k_lambda(x, lam, p_func, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * p_func(n) * x**n) / n**k_val
        for n in range(1, n_terms + 1)
    )

# Construct the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
U_expr = U_k_lambda(log_lambda_expr, lam, p_func=p_func, k_val=1, n_terms=10)
numerator = U_expr * degenerate_exp(x, t, lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Substitution values
subs_dict = {x: 0, y: 0, u: -1, k: 1}

# Evaluate polynomials symbolically with lambda -> 0
num_terms = 5
evaluated_polynomials = []

for n in range(num_terms):
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient
    T_n_subs = T_n.subs(subs_dict)
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)
    evaluated_polynomials.append(T_n_lam0)

# Print results
for n, poly in enumerate(evaluated_polynomials):
    print(f"T_hat_{{{n}}} = {poly}")
# Out:
# T_hat_{0} = 1
# T_hat_{1} = -1
# T_hat_{2} = 0
# T_hat_{3} = 2
# T_hat_{4} = 0

# %% [markdown]
# Degenerate Frobenius-type Unipoly-tangent Polynomials

# %%
import sympy as sp

# Define symbols
k, t, x, y, lam, u = sp.symbols('k t x y lambda u')

# Define the degenerate exponential: E_lambda^a(t) = (1 + lambda t)^{a / lambda}
def degenerate_exp(a, t, lam):
    return (1 + lam * t)**(a / lam)

# Define degenerate falling factorial: (a)_{n,lambda} = a (a - lambda) ... (a - (n - 1)lambda)
def degenerate_falling_factorial(a, n, lam):
    if n == 0:
        return 1
    return sp.prod(a - i * lam for i in range(n))

# Define p(n) = 1 / (n - 1)!
#def p(n):
   # return 1 / sp.factorial(n - 1)

p_func = lambda n: sp.Function('p')(n)

# Define the function u_{k, lambda}(x | p)
def U_k_lambda(x, lam, p_func, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * p_func(n) * x**n) / n**k_val
        for n in range(1, n_terms + 1)
    )

# Construct the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
U_expr = U_k_lambda(log_lambda_expr, lam, p_func=p, k_val=1, n_terms=10)
numerator = U_expr * degenerate_exp(x, t, lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Frobenius-type Unipoly-tangent Numbers (with sine)
Degenerate_Frobenius_type_unipoly_tangent_numbers = []

# Compute the first few numbers
for n in range(n_terms):
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient
    Degenerate_Frobenius_type_unipoly_tangent_numbers.append(T_n)

# Print results
for n, poly in enumerate(Degenerate_Frobenius_type_unipoly_tangent_numbers):
    print(f"T_hat_{{n,lambda,2}}^((k)) (x; u) for n={n}: {poly}")
# Out:
# T_hat_{n,lambda,2}^((k,C)) (x, y; u) with sine for n=0: 1
# T_hat_{n,lambda,2}^((k,C)) (x, y; u) with sine for n=1: x + (1 - u)*(lambda - 1)/2 + 2/(u - 1) - (-lambda*u + lambda)**2/(2*lambda*(1 - u)) + (-lambda*u + lambda)**2/(2*lambda**2*(1 - u))
# ...

# %%
#checking

import sympy as sp

# Define symbols
k, t, x, y, lam, u = sp.symbols('k t x y lambda u')

# Define the degenerate exponential: E_lambda^a(t) = (1 + lambda t)^{a / lambda}
def degenerate_exp(a, t, lam):
    return (1 + lam * t)**(a / lam)

# Define degenerate falling factorial: (a)_{n,lambda} = a (a - lambda) ... (a - (n - 1)lambda)
def degenerate_falling_factorial(a, n, lam):
    if n == 0:
        return 1
    return sp.prod(a - i * lam for i in range(n))

# Define p(n) = 1 / (n - 1)!
def p(n):
    return 1 / sp.factorial(n - 1)

# Define the function u_{k, lambda}(x | p)
def U_k_lambda(x, lam, p_func, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * p_func(n) * x**n) / n**k_val
        for n in range(1, n_terms + 1)
    )

# Construct the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
U_expr = U_k_lambda(log_lambda_expr, lam, p_func=p, k_val=1, n_terms=10)
numerator = U_expr * degenerate_exp(x, t, lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Substitution values
subs_dict = {x: 0, y: 0, u: -1, k: 1}

# Evaluate polynomials symbolically with lambda -> 0
num_terms = 5
evaluated_polynomials = []

for n in range(num_terms):
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient
    T_n_subs = T_n.subs(subs_dict)
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)
    evaluated_polynomials.append(T_n_lam0)

# Print results
for n, poly in enumerate(evaluated_polynomials):
    print(f"T_hat_{{{n}}} = {poly}")
# Out:
# T_hat_{0} = 1
# T_hat_{1} = -1
# T_hat_{2} = 0
# T_hat_{3} = 2
# T_hat_{4} = 0

# %% [markdown]
# Degenerate Frobenius-type Poly-tangent Numbers

# %%
import sympy as sp

# Define symbols
k, t, x, b, lam, u = sp.symbols('k t x b lambda u')

# Define degenerate falling factorial
def degenerate_falling_factorial(x, n, lam):
    if n == 0:
        return 1
    return sp.prod(x - i * lam for i in range(n))

# Define Ei_{k, lambda}(x)
def Ei_k_lambda(x, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * x**n) / (n**k_val * sp.factorial(n - 1))
        for n in range(1, n_terms + 1)
    )

# Define the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
numerator = Ei_k_lambda(log_lambda_expr, k_val=1)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Frobenius-type Poly-tangent Numbers
Degenerate_Frobenius_type_poly_tangent_numbers = []

# Compute the first few Degenerate Frobenius-type Poly-tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    Degenerate_Frobenius_type_poly_tangent_numbers.append(T_n)

# Print the first few Degenerate Frobenius-type Poly-tangent Numbers
for n, poly in enumerate(Degenerate_Frobenius_type_poly_tangent_numbers):
    print(f"T_(n,1)^((k))(x, u): {poly}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): (1 - u)*(lambda - 1)/2 + 2/(u - 1) - (-lambda*u + lambda)**2/(2*lambda*(1 - u)) + (-lambda*u + lambda)**2/(2*lambda**2*(1 - u))
# T_(n,1)^((k))(x, u): 2*lambda*(-1 + 2/lambda)/(u - 1) + (1 - u)**2*(lambda - 2)*(lambda - 1)/3 + 2*(1 - u)*(lambda - 1)/(u - 1) + 8/(u - 1)**2 + (1 - u)*(lambda - 1)*(-lambda*u + lambda)**2/(lambda*(u - 1)) + 2*(-lambda*u + lambda)**3/(3*lambda*(1 - u)) - 2*(-lambda*u + lambda)**2*(-2*u/(u - 1) - 2*(1 - u)/(u - 1) + 1 + 2/(u - 1))/(lambda*(1 - u)*(u - 1)) - (1 - u)*(lambda - 1)*(-lambda*u + lambda)**2/(lambda**2*(u - 1)) - (-lambda*u + lambda)**3/(lambda**2*(1 - u)) + 2*(-lambda*u + lambda)**2*(-2*u/(u - 1) - 2*(1 - u)/(u - 1) + 1 + 2/(u - 1))/(lambda**2*(1 - u)*(u - 1)) + (-lambda*u + lambda)**3/(3*lambda**3*(1 - u))
# ...

# %%
#checking 

import sympy as sp

# Define symbols
k, t, x, b, lam, u = sp.symbols('k t x b lambda u')

# Define degenerate falling factorial
def degenerate_falling_factorial(x, n, lam):
    if n == 0:
        return 1
    return sp.prod(x - i * lam for i in range(n))

# Define Ei_{k, lambda}(x)
def Ei_k_lambda(x, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * x**n) / (n**k_val * sp.factorial(n - 1))
        for n in range(1, n_terms + 1)
    )

# Define the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
numerator = Ei_k_lambda(log_lambda_expr, k_val=1)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Evaluate coefficients
num_terms = 5
subs_dict = {k: 1, u: -1}
evaluated_polynomials = []

for n in range(num_terms):
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient
    T_n_subs = T_n.subs(subs_dict)
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)
    evaluated_polynomials.append(T_n_lam0)

# Display result
for n, val in enumerate(evaluated_polynomials):
    print(f"T_({n},1)^(({k}))(0, -1): {val}")
# Out:
# T_(0,1)^((k))(0, -1): 1
# T_(1,1)^((k))(0, -1): -1
# T_(2,1)^((k))(0, -1): 0
# T_(3,1)^((k))(0, -1): 2
# T_(4,1)^((k))(0, -1): 0

# %% [markdown]
# Degenerate Frobenius-type Poly-tangent Polynomials

# %%
import sympy as sp

# Define symbols
k, t, x, b, lam, u = sp.symbols('k t x b lambda u')

# Define degenerate falling factorial
def degenerate_falling_factorial(x, n, lam):
    if n == 0:
        return 1
    return sp.prod(x - i * lam for i in range(n))

# Define Ei_{k, lambda}(x)
def Ei_k_lambda(x, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * x**n) / (n**k_val * sp.factorial(n - 1))
        for n in range(1, n_terms + 1)
    )

# Define the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
numerator = Ei_k_lambda(log_lambda_expr, k_val=1) * (1 + lam * t)**(x / lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Frobenius-type Poly-tangent Numbers
Degenerate_Frobenius_type_poly_tangent_numbers = []

# Compute the first few Degenerate Frobenius-type Poly-tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1)
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, u)
    
    # Store the polynomial
    Degenerate_Frobenius_type_poly_tangent_numbers.append(T_n)

# Print the first few Degenerate Frobenius-type Poly-tangent Numbers
for n, poly in enumerate(Degenerate_Frobenius_type_poly_tangent_numbers):
    print(f"T_(n,1)^((k))(x, u): {poly}")
# Out:
# T_(n,1)^((k))(x, u): 1
# T_(n,1)^((k))(x, u): x + (1 - u)*(lambda - 1)/2 + 2/(u - 1) - (-lambda*u + lambda)**2/(2*lambda*(1 - u)) + (-lambda*u + lambda)**2/(2*lambda**2*(1 - u))
# ...

# %%
#checking

import sympy as sp

# Define symbols
k, t, x, b, lam, u = sp.symbols('k t x b lambda u')

# Define degenerate falling factorial
def degenerate_falling_factorial(x, n, lam):
    if n == 0:
        return 1
    return sp.prod(x - i * lam for i in range(n))

# Define Ei_{k, lambda}(x)
def Ei_k_lambda(x, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * x**n) / (n**k_val * sp.factorial(n - 1))
        for n in range(1, n_terms + 1)
    )

# Define the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
numerator = Ei_k_lambda(log_lambda_expr, k_val=1) * (1 + lam * t)**(x / lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Evaluate coefficients
num_terms = 5
subs_dict = {k: 1, u: -1, x:0}
evaluated_polynomials = []

for n in range(num_terms):
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient
    T_n_subs = T_n.subs(subs_dict)
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)
    evaluated_polynomials.append(T_n_lam0)

# Display result
for n, val in enumerate(evaluated_polynomials):
    print(f"T_({n},1)^(({k}))(0, -1): {val}")
# Out:
# T_(0,1)^((k))(0, -1): 1
# T_(1,1)^((k))(0, -1): -1
# T_(2,1)^((k))(0, -1): 0
# T_(3,1)^((k))(0, -1): 2
# T_(4,1)^((k))(0, -1): 0

# %% [markdown]
# Degenerate Cosine Frobenius-type Poly-tangent Polynomials

# %%
import sympy as sp

# Define symbols
k, t, x, y, lam, u = sp.symbols('k t x y lambda u')
i = sp.I  # Imaginary unit

# Define degenerate falling factorial
def degenerate_falling_factorial(x, n, lam):
    if n == 0:
        return 1
    return sp.prod(x - m * lam for m in range(n))

# Define Ei_{k, lambda}(x)
def Ei_k_lambda(x, lam, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * x**n) / (n**k_val * sp.factorial(n - 1))
        for n in range(1, n_terms + 1)
    )

# Define the degenerate exponential function e_lambda^a(t)
def degenerate_exp(a, t, lam):
    return (1 + lam * t)**(a / lam)

# Define the degenerate cosine function
def degenerate_cos(y, t, lam):
    return (degenerate_exp(i * y, t, lam) + degenerate_exp(-i * y, t, lam)) / 2

# Define the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
Ei_expr = Ei_k_lambda(log_lambda_expr, lam, k_val=1)
numerator = Ei_expr * degenerate_exp(x, t, lam) * degenerate_cos(y, t, lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 6

# List to store the Degenerate Frobenius-type Poly-tangent Numbers
Degenerate_Frobenius_type_poly_tangent_numbers = []

# Compute the first few Degenerate Frobenius-type Poly-tangent Numbers
for n in range(n_terms):
    # Expand the generating function in a Taylor series around t = 0 up to order n + 1
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    
    # Extract the coefficient of t^n and multiply by n! to get the polynomial
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient  # multiply by n! to get T_n(x, y, u)
    
    # Store the polynomial
    Degenerate_Frobenius_type_poly_tangent_numbers.append(T_n)

# Print the first few Degenerate Frobenius-type Poly-tangent Numbers
for n, poly in enumerate(Degenerate_Frobenius_type_poly_tangent_numbers):
    print(f"T_hat_{{n,lambda,2}}^((k,C)) (x, y; u) for n={n}: {poly}")

# %%
#checking

import sympy as sp

# Define symbols
k, t, x, y, lam, u = sp.symbols('k t x y lambda u')
i = sp.I  # Imaginary unit

# Define degenerate falling factorial
def degenerate_falling_factorial(x, n, lam):
    if n == 0:
        return 1
    return sp.prod(x - i * lam for i in range(n))

# Define Ei_{k, lambda}(x)
def Ei_k_lambda(x, lam, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * x**n) / (n**k_val * sp.factorial(n - 1))
        for n in range(1, n_terms + 1)
    )

# Define the degenerate exponential function e_lambda^a(t)
def degenerate_exp(a, t, lam):
    return (1 + lam * t)**(a / lam)

# Define the degenerate cosine function
def degenerate_cos(y, t, lam):
    return (degenerate_exp(i * y, t, lam) + degenerate_exp(-i * y, t, lam)) / 2

# Define the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
Ei_expr = Ei_k_lambda(log_lambda_expr, lam, k_val=1)
numerator = Ei_expr * degenerate_exp(x, t, lam) * degenerate_cos(y, t, lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Evaluate coefficients
num_terms = 5
subs_dict = {k: 1, u: -1, x: 0, y: 0}
evaluated_polynomials = []

for n in range(num_terms):
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient
    T_n_subs = T_n.subs(subs_dict)
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)
    evaluated_polynomials.append(T_n_lam0)

# Print the first few Degenerate Frobenius-type Poly-tangent Numbers
for n, poly in enumerate(evaluated_polynomials):
    print(f"T_hat_{{n,lambda,2}}^((k,C)) (x, y; u): {poly}")
# Out:
# T_hat_{n,lambda,2}^((k,C)) (x, y; u): 1
# T_hat_{n,lambda,2}^((k,C)) (x, y; u): -1
# T_hat_{n,lambda,2}^((k,C)) (x, y; u): 0
# T_hat_{n,lambda,2}^((k,C)) (x, y; u): 2
# T_hat_{n,lambda,2}^((k,C)) (x, y; u): 0

# %% [markdown]
# Degenerate Sine Frobenius-type Poly-tangent Polynomials

# %%
import sympy as sp

# Define symbols
k, t, x, y, lam, u, m = sp.symbols('k t x y lambda u m')
i = sp.I  # Imaginary unit

# Define degenerate falling factorial
def degenerate_falling_factorial(x, n, lam):
    if n == 0:
        return 1
    return sp.prod(x - m * lam for m in range(n))

# Define Ei_{k, lambda}(x)
def Ei_k_lambda(x, lam, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * x**n) / (n**k_val * sp.factorial(n - 1))
        for n in range(1, n_terms + 1)
    )

# Define the degenerate exponential function e_lambda^a(t)
def degenerate_exp(a, t, lam):
    return (1 + lam * t)**(a / lam)

# Define the degenerate sine function
def degenerate_sin(y, t, lam):
    return (degenerate_exp(i * y, t, lam) - degenerate_exp(-i * y, t, lam)) / (2 * i)
    # Alternatively, use the closed-form definition from the image:
    # return sp.sin((y / lam) * sp.log(1 + lam * t))

# Define the generating function with sine
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
Ei_expr = Ei_k_lambda(log_lambda_expr, lam, k_val=1)
numerator = Ei_expr * degenerate_exp(x, t, lam) * degenerate_sin(y, t, lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# List to store the Degenerate Frobenius-type Poly-tangent Numbers (with sine)
Degenerate_Frobenius_type_poly_tangent_numbers = []

# Compute the first few numbers
for n in range(n_terms):
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient
    Degenerate_Frobenius_type_poly_tangent_numbers.append(T_n)

# Print results
for n, poly in enumerate(Degenerate_Frobenius_type_poly_tangent_numbers):
    print(f"T_hat_{{n,lambda,2}}^((k,S)) (x, y; u) with sine for n={n}: {poly}")

# %%
import sympy as sp

# Define symbols
k, t, x, y, lam, u = sp.symbols('k t x y lambda u')
i = sp.I  # Imaginary unit

# Define degenerate falling factorial
def degenerate_falling_factorial(x, n, lam):
    if n == 0:
        return 1
    return sp.prod(x - i * lam for i in range(n))

# Define Ei_{k, lambda}(x)
def Ei_k_lambda(x, lam, k_val=1, n_terms=10):
    return sum(
        (degenerate_falling_factorial(1, n, lam) * x**n) / (n**k_val * sp.factorial(n - 1))
        for n in range(1, n_terms + 1)
    )

# Define the degenerate exponential function e_lambda^a(t)
def degenerate_exp(a, t, lam):
    return (1 + lam * t)**(a / lam)

# Define the degenerate cosine function
def degenerate_sin(y, t, lam):
    return sp.sin((y / lam) * sp.log(1 + lam * t))

# Define the generating function
log_lambda_expr = (1 / lam) * ((1 + (1 - u) * t)**lam - 1)
Ei_expr = Ei_k_lambda(log_lambda_expr, lam, k_val=1)
numerator = Ei_expr * degenerate_exp(x, t, lam) * degenerate_sin(y, t, lam)
denominator = t * ((1 + lam * t)**(2 / lam) - u)
generating_function = numerator / denominator

# Evaluate coefficients
num_terms = 5
subs_dict = {k: 1, u: -1, x: 0, y: 0}
evaluated_polynomials = []

for n in range(num_terms):
    series_expansion = sp.series(generating_function, t, 0, n + 1).removeO()
    coefficient = series_expansion.coeff(t, n)
    T_n = sp.factorial(n) * coefficient
    T_n_subs = T_n.subs(subs_dict)
    T_n_lam0 = sp.limit(T_n_subs, lam, 0)
    evaluated_polynomials.append(T_n_lam0)

# Print the first few Degenerate Frobenius-type Poly-tangent Numbers
for n, poly in enumerate(evaluated_polynomials):
    print(f"T_hat_{{n,lambda,2}}^((k,S)) (x, y; u) with sine for n={n}: {poly}")
# Out:
# T_hat_{n,lambda,2}^((k,S)) (x, y; u) with sine for n=0: 0
# T_hat_{n,lambda,2}^((k,S)) (x, y; u) with sine for n=1: 0
# T_hat_{n,lambda,2}^((k,S)) (x, y; u) with sine for n=2: 0
# T_hat_{n,lambda,2}^((k,S)) (x, y; u) with sine for n=3: 0
# T_hat_{n,lambda,2}^((k,S)) (x, y; u) with sine for n=4: 0
